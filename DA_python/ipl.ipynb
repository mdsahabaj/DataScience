# %%
#Loading the required library
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#Loading the ipl dataset
ipl=pd.read_csv("/home/md/Desktop/ipl/matches.csv")

# %%
#Having a glance of first five records of the dataset
ipl.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
#looking how many rows and columns are there in the dataset
ipl.shape
# Out:
# (636, 18)

# %%
#Getting the frequency of the most man of the match awards
ipl["player_of_match"].value_counts()
# Out:
# CH Gayle          18
# YK Pathan         16
# AB de Villiers    15
# DA Warner         15
# SK Raina          14
#                   ..
# R McLaren          1
# BCJ Cutting        1
# CR Brathwaite      1
# MA Starc           1
# KS Williamson      1
# Name: player_of_match, Length: 201, dtype: int64

# %%
#Getting the top 10 player who got most man of the match
ipl["player_of_match"].value_counts()[0:10]
# Out:
# CH Gayle          18
# YK Pathan         16
# AB de Villiers    15
# DA Warner         15
# SK Raina          14
# RG Sharma         14
# MS Dhoni          13
# G Gambhir         13
# MEK Hussey        12
# AM Rahane         12
# Name: player_of_match, dtype: int64

# %%
#Getting the top 5 player who got most man of the match
ipl["player_of_match"].value_counts()[0:5]
# Out:
# CH Gayle          18
# YK Pathan         16
# AB de Villiers    15
# DA Warner         15
# SK Raina          14
# Name: player_of_match, dtype: int64

# %%
#making a bar plot of the top 5 man the matche awards
plt.figure(figsize=(8,5))
plt.bar(list(ipl["player_of_match"].value_counts()[0:5].keys()),list(ipl["player_of_match"].value_counts()[0:5]),color='r')
plt.show()

# %%
#Getting the frequency of result column 
ipl['result'].value_counts()
# Out:
# normal       626
# tie            7
# no result      3
# Name: result, dtype: int64

# %%
#finding out no of toss win each team
ipl['toss_winner'].value_counts()
# Out:
# Mumbai Indians                 85
# Kolkata Knight Riders          78
# Delhi Daredevils               72
# Royal Challengers Bangalore    70
# Kings XI Punjab                68
# Chennai Super Kings            66
# Rajasthan Royals               63
# Deccan Chargers                43
# Sunrisers Hyderabad            35
# Pune Warriors                  20
# Gujarat Lions                  15
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: toss_winner, dtype: int64

# %%
#how many times a team choose bat and bowl after winning the toss
ipl['toss_decision'].value_counts()
# Out:
# field    363
# bat      273
# Name: toss_decision, dtype: int64

# %%
#how many times a team won after  bating first
batting_first=ipl[ipl['win_by_runs']!=0]
batting_first.shape
# Out:
# (287, 18)

# %%
#how many times a team won after bowling first
bowling_first=ipl[ipl['win_by_runs']==0]
bowling_first.shape
# Out:
# (349, 18)

# %%
#how many times a team won after  winning the toss and bat first
batting_first_won_toss=ipl[ipl['toss_decision']=='bat']
batting_first_won=batting_first_won_toss[batting_first_won_toss['win_by_runs']!=0]
batting_first_won.shape
# Out:
# (126, 18)

# %%
#how many times a team won after  winning the toss and bowl first
bowling_first_won_toss=ipl[ipl['toss_decision']=='field']
bowling_first_won=bowling_first_won_toss[bowling_first_won_toss['win_by_wickets']!=0]
bowling_first_won.shape
# Out:
# (196, 18)

# %%
#making a histogram of batting first winning runs
#batting_first=ipl[ipl['win_by_runs']!=0]
plt.figure(figsize=(5,5))
plt.hist(batting_first['win_by_runs'])
plt.xlabel('runs')
plt.title('Distribution of runs')
plt.show()

# %%
#want to  see batting first team dataset
batting_first=ipl[ipl['win_by_runs']!=0]
batting_first
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 8      9    2017           Pune  2017-04-11             Delhi Daredevils
# 13    14    2017        Kolkata  2017-04-15        Kolkata Knight Riders
# 14    15    2017          Delhi  2017-04-15             Delhi Daredevils
# ..   ...     ...            ...         ...                          ...
# 624  625    2016  Visakhapatnam  2016-05-17             Delhi Daredevils
# 625  626    2016      Bangalore  2016-05-18  Royal Challengers Bangalore
# 630  631    2016        Kolkata  2016-05-22        Kolkata Knight Riders
# 633  634    2016          Delhi  2016-05-25          Sunrisers Hyderabad
# 635  636    2016      Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
#finding out no of wins of each team after batting first
batting_first['winner'].value_counts()
# Out:
# Mumbai Indians                 47
# Chennai Super Kings            46
# Kings XI Punjab                32
# Kolkata Knight Riders          31
# Royal Challengers Bangalore    30
# Rajasthan Royals               23
# Sunrisers Hyderabad            23
# Delhi Daredevils               21
# Deccan Chargers                18
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Rising Pune Supergiants         2
# Kochi Tuskers Kerala            2
# Gujarat Lions                   1
# Name: winner, dtype: int64

# %%
#finding out no of wins of each team after bowiling first
bowling_first['winner'].value_counts()
# Out:
# Kolkata Knight Riders          46
# Mumbai Indians                 45
# Royal Challengers Bangalore    43
# Delhi Daredevils               41
# Rajasthan Royals               40
# Kings XI Punjab                38
# Chennai Super Kings            33
# Sunrisers Hyderabad            19
# Gujarat Lions                  12
# Deccan Chargers                11
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            4
# Rising Pune Supergiants         3
# Name: winner, dtype: int64

# %%
#making a bar plot of the top 3 teams with most wins after batting first
plt.figure(figsize=(8,5))
plt.bar(list(batting_first["winner"].value_counts()[0:3].keys()),list(batting_first["winner"].value_counts()[0:3]),color=['b','y','r'])
plt.show()

# %%
#winning percentage distribution  after batting first using pie chart
plt.figure(figsize=(8,8))
plt.pie(list(batting_first["winner"].value_counts()),labels=list(batting_first["winner"].value_counts().keys()),autopct="%0.1f%%")
plt.show()

# %%
#Looking no of total matches played in each season
ipl['season'].value_counts()
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2016    60
# 2014    60
# 2010    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %%
#Looking no of total matches played in each city
ipl['city'].value_counts()
# Out:
# Mumbai            85
# Bangalore         66
# Kolkata           61
# Delhi             60
# Hyderabad         49
# Chennai           48
# Chandigarh        46
# Jaipur            33
# Pune              32
# Durban            15
# Centurion         12
# Ahmedabad         12
# Visakhapatnam     11
# Rajkot            10
# Dharamsala         9
# Johannesburg       8
# Cape Town          7
# Cuttack            7
# Ranchi             7
# Port Elizabeth     7
# Abu Dhabi          7
# Raipur             6
# Sharjah            6
# Indore             5
# Kochi              5
# Kanpur             4
# Nagpur             3
# East London        3
# Kimberley          3
# Bloemfontein       2
# Name: city, dtype: int64

# %%
ipl.head(
)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
#how many times dl applied season wise
dl=ipl[ipl['dl_applied']==1]
dl['season'].value_counts()
# Out:
# 2016    4
# 2011    3
# 2009    3
# 2015    2
# 2008    2
# 2014    1
# 2017    1
# Name: season, dtype: int64

# %%
ipl.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
#winning percentage of rcb till 2017
rcb_team1=ipl[ipl['team1']=='Royal Challengers Bangalore']
rcb_team2=ipl[ipl['team2']=='Royal Challengers Bangalore']
rcb_total_match=pd.concat([rcb_team1,rcb_team2])
rcb_total_match
# Out:
#       id  season       city        date                        team1  \
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 7      8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 11    12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
# 19    20    2017     Rajkot  2017-04-18  Royal Challengers Bangalore
# 29    30    2017  Bangalore  2017-04-27  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 610  611    2016  Bangalore  2016-05-07      Rising Pune Supergiants
# 623  624    2016    Kolkata  2016-05-16        Kolkata Knight Riders
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
toatal_match=len(rcb_total_match)

# %%
rcb_win=ipl[ipl["winner"]=='Royal Challengers Bangalore']

# %%
rcb_no_wins=len(rcb_win)

# %%
rcb_wp=(len(rcb_win)/len(rcb_total_match))*100
print(rcb_wp,"%")
# Out:
# 48.026315789473685 %
