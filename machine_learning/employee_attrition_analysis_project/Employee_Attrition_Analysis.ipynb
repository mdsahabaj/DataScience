# %%
#importing the enviroment
import pandas as pd 
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#importing the data from jupyter notebook
data=pd.read_csv("/home/md/Data_Analysis/Projects/Employee_Attirition_Analysis_using_Random_Forest/Employee_Attrition.csv")

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
#checking number of rows and columns
data.shape
# Out:
# (1470, 35)

# %%
#summerize the datasets
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
#checking any null value present in the dataset
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#lets check attrition total attrition count
attrition_count=data['Attrition'].value_counts()   #to extract only value use value_counts()[index position]-1233
attrition_count                                     #extract key VC().index.tolist()[index position]-NO
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
#checking total percentage of attrition
total_employee=len(data)  #total no of records means total no of employee
attrition_percentage=(data['Attrition'].value_counts()[1])*100/total_employee

# %%
attrition_percentage
# Out:
# 16.122448979591837

# %%
# #crosschecking
# attrition_count=data['Attrition'].value_counts('Yes')
# attrition_count

# %%
#creating a bar plot
sns.countplot(data['Attrition'])
plt.show()
# Out:
# /home/md/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#creating a pie chart to show how much percentage of total people attriated
plt.pie(attrition_count,labels=['No','Yes'],autopct='%0.1f%%',explode=(0.3,0))
plt.show()

# %%
#dropping irrelevant columns
data=data.drop(['EmployeeCount','EmployeeNumber'],axis=1)

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %%
#creating dummies for attrition,changing yes no to 0 and 1
attrition_dummies=pd.get_dummies(data['Attrition']) #It converts categorical data into dummy or indicator variables.
attrition_dummies.head()
# Out:
#    No  Yes
# 0   0    1
# 1   1    0
# 2   0    1
# 3   1    0
# 4   1    0

# %%
#concat the both dataframe in columnwise
data=pd.concat([data,attrition_dummies],axis=1)
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# ...

# %%
#drop any one column from yes and no because using one column is sufficient
data=data.drop(['No'],axis=1)
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  StandardHours  StockOptionLevel  TotalWorkingYears  \
# ...

# %%
# #crosscheck
# count=data['Yes'].value_counts()
# count

# %%
#lets check which gender is attrition is more using bar plot
sns.barplot(x='Gender',y='Yes', data=data)
plt.show()

# %%
#lets check which Department is attrition is more using bar plot
sns.barplot(x='Department',y='Yes', data=data)
plt.show()

# %%
#lets check which Business Travel is attrition is more using bar plot
sns.barplot(x='BusinessTravel',y='Yes', data=data)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data.corr())
plt.show()

# %%
#dropping some least corelation columns
data=data.drop(['Age','JobLevel'],axis=1)

# %% [markdown]
# ## Data Preprossing

# %%
# #converting string data into integer for model feeding
# from sklearn.preprocessing import LabelEncoder
# for column in data.columns:
#     if data[column].dtype==np.number:
#         continue
#     else:
#         data[column]=LabelEncoder().fit_transform(data[column])
from sklearn.preprocessing import LabelEncoder
for column in data.columns:
    if data[column].dtypes==object:
        data[column]=LabelEncoder().fit_transform(data[column])
    else:
        continue

# %%
data.head()
# Out:
#    Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0          1               2       1102           2                 1
# 1          0               1        279           1                 8
# 2          1               2       1373           1                 2
# 3          0               1       1392           1                 3
# 4          0               2        591           1                 2
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0          2               1                        2       0          94
# 1          1               1                        3       1          61
# 2          2               4                        4       1          92
# 3          4               1                        4       0          56
# 4          1               3                        1       1          40
#
#    ...  StandardHours  StockOptionLevel  TotalWorkingYears  \
# ...

# %% [markdown]
# # Model Building

# %%
#importing libraies
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=10,criterion='entropy',random_state=0)

# %%
x=data.drop(['Yes'],axis=1)
y=data['Yes']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
x_train.head()
# Out:
#      Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 338          0               2        570           2                 5
# 363          1               2        350           2                 5
# 759          0               2        788           0                24
# 793          0               2        895           1                15
# 581          0               2        921           1                 1
#
#      Education  EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# 338          3               2                        4       0          30
# 363          3               2                        4       0          34
# 759          4               3                        2       1          36
# 793          2               1                        1       1          50
# 581          3               1                        4       1          38
#
#      ...  RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %%
y_train.head()
# Out:
# 338    0
# 363    1
# 759    0
# 793    0
# 581    0
# Name: Yes, dtype: uint8

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
rf.score(x_train,y_train)
# Out:
# 0.9990281827016521

# %% [markdown]
# ## predicting for x_test

# %%
pred=rf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,pred)
# Out:
# 0.9977324263038548
